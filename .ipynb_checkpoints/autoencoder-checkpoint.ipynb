# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='-1'    

import pandas as pd
import numpy as np
import sklearn.preprocessing as p
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split
import keras.layers as l
from keras.models import Sequential

# %%
data = pd.read_csv('input/data_before.csv')
data.shape
# Out:
# c:\users\aferraresso\appdata\local\programs\python\python35\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (49,51,65,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (14337, 108)

# %%
data.fillna(0, inplace=True)

# %%
labels = [c for c in data.columns if 'mode' in c]
num_cols = [c for c in data.columns if c not in labels]

# %%
train_test_split(y, shuffle=False)
[[0, 1, 2], [3, 4]]

# %%
scaler = p.StandardScaler()
scaler.fit(data[num_cols])
X = scaler.transform(data[num_cols])
train, test = train_test_split(X, test_s)

# %%
model = Sequential()
model.add(l.Dense(100, activation='relu',input_shape=(X.shape[1],)))
model.add(l.Dropout(0.2))
# model.add(l.Dense(80, activation='relu'))
model.add(l.Dense(80, activation='linear'))
# model.add(l.Dense(80, activation='relu'))
model.add(l.Dense(100, activation='relu'))
model.add(l.Dropout(0.2))
model.add(l.Dense(X.shape[1], activation='linear'))
model.compile(optimizer='adam', loss='mse')

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_17 (Dense)             (None, 100)               9700
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 80)                8080
# _________________________________________________________________
# dense_19 (Dense)             (None, 100)               8100
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 96)                9696
# ...
# Total params: 35,576
# Trainable params: 35,576
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
def plotit(history, min_epoch=0, show_all=True):
    legends = []
    if show_all:
        for val in history.history:
            plt.plot(history.history[val][min_epoch:])
            legends.append(val)
    else:
        plt.plot(history.history['loss'][min_epoch:])
        plt.plot(history.history['val_loss'][min_epoch:])
        legends = ['loss','val_loss']
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(legends, loc='upper left')
    plt.show()

# %%
history = model.fit(X,X, batch_size=512, epochs=500, validation_split=0.05)
# Out:
# Train on 13620 samples, validate on 717 samples
# Epoch 1/500
# 13620/13620 [==============================] - ETA: 0s - loss: 0.605 - 1s 42us/step - loss: 0.7617 - val_loss: 0.1966
# Epoch 2/500
# 13620/13620 [==============================] - 0s 12us/step - loss: 0.5470 - val_loss: 0.1369
# Epoch 3/500
# 13620/13620 [==============================] - 0s 11us/step - loss: 0.4068 - val_loss: 0.1146
# Epoch 4/500
# 13620/13620 [==============================] - 0s 11us/step - loss: 0.3596 - val_loss: 0.1040
# Epoch 5/500
# 13620/13620 [==============================] - 0s 11us/step - loss: 0.3377 - val_loss: 0.0957
# Epoch 6/500
# 13620/13620 [==============================] - 0s 11us/step - loss: 0.3072 - val_loss: 0.0918
# Epoch 7/500
# 13620/13620 [==============================] - 0s 11us/step - loss: 0.2986 - val_loss: 0.0832
# Epoch 8/500
# 13620/13620 [==============================] - 0s 11us/step - loss: 0.2369 - val_loss: 0.0807
# Epoch 9/500
# ...

# %%
plotit(history)

# %%
infected = pd.read_csv('input/data_infected.csv')
infected.fillna(0, inplace=True)
iX = scaler.transform(infected[num_cols])
# Out:
# c:\users\aferraresso\appdata\local\programs\python\python35\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (49,51,65,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
model.evaluate(iX,iX)
# Out:
# 29407/29407 [==============================] - 1s 26us/step
# 19771.024135654694

# %%
after = pd.read_csv('input/data_after.csv')
after.fillna(0, inplace=True)
aX = scaler.transform(after[num_cols])
# Out:
# c:\users\aferraresso\appdata\local\programs\python\python35\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (51,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
model.evaluate(aX,aX)
# Out:
# 8629/8629 [==============================] - 0s 27us/step
# 40.420257588077206

# %%
x_pred = model.predict(X)

# %%
i_pred = model.predict(iX)

# %%
a_pred = model.predict(aX)

# %%
before_error = ((X - x_pred) ** 2).mean(axis=-1) 
infected_error = ((iX - i_pred) ** 2).mean(axis=-1)
after_error = ((aX - a_pred) ** 2).mean(axis=-1)

# %%
errors = np.concatenate([np.clip(before_error,0,2), np.clip(infected_error,0,2), np.clip(after_error,0,2)])
print(errors.shape)
# Out:
# (52373,)

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)

# %%
plt.plot(running_mean(errors, 1000))
plt.title('Mean squared error')
plt.axvline(x=14337, color='red')
plt.axvline(x=14337+29407, color='green')
plt.ylabel('error')
plt.xlabel('time')
plt.show()
